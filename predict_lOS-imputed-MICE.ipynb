# %% [markdown]
# ### This is the version of 4 regression models using Imputed_MICE_RandomForest data with 'DRG PROGRAM' grouped.

# %%
# IMPORT MODULES

import os
from operator import itemgetter    
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
get_ipython().magic(u'matplotlib inline')
plt.style.use('ggplot')

from sklearn.model_selection import StratifiedShuffleSplit

from sklearn.tree import DecisionTreeRegressor
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import RobustScaler, StandardScaler, LabelEncoder, MinMaxScaler, OneHotEncoder, LabelBinarizer
from sklearn.metrics import mean_squared_error, accuracy_score, mean_absolute_error
#from sklearn.cross_validation import KFold, cross_val_score
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV, KFold, cross_val_predict, StratifiedKFold, train_test_split, learning_curve, ShuffleSplit
from sklearn.model_selection import train_test_split
from sklearn import model_selection, preprocessing
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV,KFold, cross_val_predict, StratifiedKFold, train_test_split, learning_curve, ShuffleSplit
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC 
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, ShuffleSplit
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score, f1_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve, average_precision_score, auc
# from sklearn.utils.fixes import signature
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

from mlxtend.plotting import plot_learning_curves
from mlxtend.preprocessing import shuffle_arrays_unison
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error, r2_score

# %%
# import tensorflow as tf
# from keras import models, regularizers, layers, optimizers, losses, metrics
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.utils import np_utils
# from keras.utils import to_categorical

print(os.getcwd())
print("Modules imported \n")
import os
# print(os.listdir("../input/"))
# Out:
# /Users/aurorazheng/Documents/datafest
# Modules imported

# %%
data = pd.read_excel('../datafest/Imputed_MICE_RandomForest.xlsx')
print("With id", data.shape)
data_full = data
print("No id",data_full.shape)
# Out:
# With id (474, 22)
# No id (474, 22)

# %%
df_los = data_full.dropna(subset=['LOS'])
df_los
# Out:
#      TC_ID Request Status           Transfer Referral Source          County  \
# 0       43       Accepted                  Mercy Bakersfield         Arcadia
# 1      155       Accepted  Presbyterian Intercommunity (Pih)        Whittier
# 2      340       Accepted               Bakersfield Memorial         Arcadia
# 3      433       Accepted             Norris Cancer Hospital         Arcadia
# 4      440       Accepted             Hollywood Presbyterian   Citrus Valley
# ..     ...            ...                                ...             ...
# 469  48195       Accepted                Valley Presbyterian    Apple Valley
# 470  48256       Accepted                      Verdugo Hills    Apple Valley
# 471  48420       Accepted                     County Lac Usc   Citrus Valley
# 472  48526       Accepted                           Garfield   Citrus Valley
# 473  48531       Accepted                           Garfield         Arcadia
#
#      Transfer Back Agreement  LOA (Mark X if Yes)  \
# 0                       True                False
# 1                       True                False
# 2                      False                False
# 3                      False                False
# 4                      False                False
# ..                       ...                  ...
# 469                     True                False
# 470                    False                False
# 471                     True                False
# 472                    False                False
# 473                    False                False
#
#      Accepting Physician Specialty Required Level Of Care  \
# 0              Surgery, Colorectal               Med/Surg
# 1                 Neurology-Stroke               Med/Surg
# 2                Surgery, Otorhino                    ICU
# 3                  Surgery, Trauma                    ICU
# 4                       Nephrology               Med/Surg
# ..                             ...                    ...
# 469  Internal Medicin- Hospitalist              Telemetry
# 470                     Cardiology               Stepdown
# 471               Surgery, Orthope               Med/Surg
# 472        Surgery, Neurolo- Spine               Med/Surg
# 473       Surgery, General- Hepato               Med/Surg
#
#     Requested Treatment Intervention  \
# 0                Orthopaedic Surgery
# 1    Medical Management/Optimization
# 2                Orthopaedic Surgery
# 3        Surgical Evaluation/Surgery
# 4                           Ohns/Ent
# ..                               ...
# 469      Surgical Evaluation/Surgery
# 470                         Ohns/Ent
# 471      Surgical Evaluation/Surgery
# 472              Orthopaedic Surgery
# 473              Orthopaedic Surgery
#
#     From Where Patient Admitted to Referring Facility  ...  \
# 0                                         Acute Rehab  ...
# 1                                         Acute Rehab  ...
# 2                                         Acute Rehab  ...
# 3                                                  ER  ...
# 4                                         Acute Rehab  ...
# ..                                                ...  ...
# 469                                                ER  ...
# 470                                       Acute Rehab  ...
# 471                                              Home  ...
# 472                                                ER  ...
# 473                                       Acute Rehab  ...
#
#     EMTALA Y/N(Patient Status Details) Special Considerations  Gender  \
# 0                                   No              Bloodless  Female
# 1                                   No              Bloodless    Male
# 2                                   No              Bloodless  Female
# 3                                   No              Bloodless  Female
# 4                                   No              Bloodless  Female
# ..                                 ...                    ...     ...
# 469                                 No              Bloodless  Female
# 470                                 No              Bloodless  Female
# 471                                 No              Bloodless  Female
# 472                                 No              Bloodless  Female
# 473                                 No              Bloodless  Female
#
#                          DRG Program                  Payor    LOS ICU LOS  \
# 0               Lower Joint Revision  Medicaid Managed Care   6.54    1.82
# 1                           Lymphoma  Medicare Managed Care   6.00    3.00
# 2                       Hem-Oncology               Medicaid   6.13    1.56
# 3                 Infectious Disease       Managed Exchange   2.00    2.00
# 4                 Infectious Disease               Medicaid   6.58    1.40
# ..                               ...                    ...    ...     ...
# 469                Other Gi Medicine  Medicaid Managed Care   6.00    0.00
# 470  Percutaneous Cardiac Procedures               Medicare   2.00    0.00
# 471                  Fracture/Injury               Medicare   5.00    0.00
# 472               Infectious Disease               Medicaid   6.23    0.14
# 473            Hepatobiliary Surgery               Medicare  22.00    2.00
#
#      LOS Outlier  Discharge Disposition   Age
# 0    Not Outlier      Intermediate Care  78.0
# 1    Not Outlier     Acute-Another Hosp  56.0
# 2    Not Outlier        Home Health Org  60.0
# 3    Not Outlier                Expired  53.0
# 4    Not Outlier                Expired  42.0
# ..           ...                    ...   ...
# 469      Outlier         Home/Self Care  63.0
# 470  Not Outlier         Home/Self Care  75.0
# 471  Not Outlier        Home Health Org  46.0
# 472  Not Outlier        Home Health Org  49.0
# 473      Outlier                    SNF  86.0
#
# [474 rows x 22 columns]

# %% [markdown]
# tensorflow not supported for python 3.8

# %%
data_full.info()
data_full.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 22 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   TC_ID                                              474 non-null    int64
#  1   Request Status                                     474 non-null    object
#  2   Transfer Referral Source                           474 non-null    object
#  3   County                                             474 non-null    object
#  4   Transfer Back Agreement                            474 non-null    bool
#  5   LOA (Mark X if Yes)                                474 non-null    bool
#  6   Accepting Physician Specialty                      474 non-null    object
#  7   Required Level Of Care                             474 non-null    object
#  8   Requested Treatment Intervention                   474 non-null    object
#  9   From Where Patient Admitted to Referring Facility  474 non-null    object
#  10  Infection Precaution                               474 non-null    object
#  11  Patient Status                                     474 non-null    object
#  12  EMTALA Y/N(Patient Status Details)                 474 non-null    object
#  13  Special Considerations                             474 non-null    object
#  14  Gender                                             474 non-null    object
#  15  DRG Program                                        474 non-null    object
#  16  Payor                                              474 non-null    object
#  17  LOS                                                474 non-null    float64
#  18  ICU LOS                                            474 non-null    float64
#  19  LOS Outlier                                        474 non-null    object
#  20  Discharge Disposition                              474 non-null    object
#  21  Age                                                474 non-null    float64
# dtypes: bool(2), float64(3), int64(1), object(16)
# memory usage: 75.1+ KB
#               TC_ID         LOS     ICU LOS         Age
# count    474.000000  474.000000  474.000000  474.000000
# mean   23446.607595    8.790127    2.526962   58.485781
# std    14189.722432   11.751631    8.831258   17.114172
# min       43.000000    1.000000    0.000000   18.000000
# 25%    11013.250000    4.000000    0.000000   46.135000
# 50%    22680.000000    6.000000    0.140000   60.000000
# 75%    35168.250000    8.000000    1.000000   71.000000
# max    48531.000000  132.000000  132.000000   90.000000

# %%
data_full.head(5)
# Out:
#    TC_ID Request Status           Transfer Referral Source          County  \
# 0     43       Accepted                  Mercy Bakersfield         Arcadia
# 1    155       Accepted  Presbyterian Intercommunity (Pih)        Whittier
# 2    340       Accepted               Bakersfield Memorial         Arcadia
# 3    433       Accepted             Norris Cancer Hospital         Arcadia
# 4    440       Accepted             Hollywood Presbyterian   Citrus Valley
#
#    Transfer Back Agreement  LOA (Mark X if Yes) Accepting Physician Specialty  \
# 0                     True                False           Surgery, Colorectal
# 1                     True                False              Neurology-Stroke
# 2                    False                False             Surgery, Otorhino
# 3                    False                False               Surgery, Trauma
# 4                    False                False                    Nephrology
#
#   Required Level Of Care Requested Treatment Intervention  \
# 0               Med/Surg              Orthopaedic Surgery
# 1               Med/Surg  Medical Management/Optimization
# 2                    ICU              Orthopaedic Surgery
# 3                    ICU      Surgical Evaluation/Surgery
# 4               Med/Surg                         Ohns/Ent
#
#   From Where Patient Admitted to Referring Facility  ...  \
# 0                                       Acute Rehab  ...
# 1                                       Acute Rehab  ...
# 2                                       Acute Rehab  ...
# 3                                                ER  ...
# 4                                       Acute Rehab  ...
#
#   EMTALA Y/N(Patient Status Details) Special Considerations  Gender  \
# 0                                 No              Bloodless  Female
# 1                                 No              Bloodless    Male
# 2                                 No              Bloodless  Female
# 3                                 No              Bloodless  Female
# 4                                 No              Bloodless  Female
#
#             DRG Program                  Payor   LOS ICU LOS  LOS Outlier  \
# 0  Lower Joint Revision  Medicaid Managed Care  6.54    1.82  Not Outlier
# 1              Lymphoma  Medicare Managed Care  6.00    3.00  Not Outlier
# 2          Hem-Oncology               Medicaid  6.13    1.56  Not Outlier
# 3    Infectious Disease       Managed Exchange  2.00    2.00  Not Outlier
# 4    Infectious Disease               Medicaid  6.58    1.40  Not Outlier
#
#    Discharge Disposition   Age
# 0      Intermediate Care  78.0
# 1     Acute-Another Hosp  56.0
# 2        Home Health Org  60.0
# 3                Expired  53.0
# 4                Expired  42.0
#
# [5 rows x 22 columns]

# %%
# Label = LOS
# the attributes that is NOT related to LOS
y = df_los['LOS']
X = df_los.drop('LOS', 1)
X = X.drop('LOA (Mark X if Yes)', 1)
X = X.drop('From Where Patient Admitted to Referring Facility', 1)
X = X.drop('EMTALA Y/N(Patient Status Details)', 1)
X = X.drop('Special Considerations', 1)
X = X.drop('Transfer Back Agreement', 1)
X = X.drop('Transfer Referral Source', 1)
X = X.drop('Infection Precaution',1)
X = X.drop('Request Status',1)

print("y - Labels", y.shape)
print("X - No Label No id ", X.shape)
print(X.columns)
# Out:
# y - Labels (474,)
# X - No Label No id  (474, 13)
# Index(['TC_ID', 'County', 'Accepting Physician Specialty',
#        'Required Level Of Care', 'Requested Treatment Intervention',
#        'Patient Status', 'Gender', 'DRG Program', 'Payor', 'ICU LOS',
#        'LOS Outlier', 'Discharge Disposition', 'Age'],
#       dtype='object')

# %% [markdown]
# Based on discussion, the features and attributes that we care most are Patient Status, DRG PROGRAM, LOS Outlier, Discharge Disposition and Age. let's see how each of them distributed.

# %%
df_los.groupby('LOS').size().plot.bar()
plt.show()

# %%
df_los.groupby('Patient Status').size().plot.bar()
plt.show()

# %%
df_los.groupby('DRG Program').size().plot.bar()
plt.show()

# %% [markdown]
# #### group the lower portion of categories to one bigger categories, clean the data, lowercase

# %%
total = df_los['DRG Program'].count()
value_counts = df_los['DRG Program'].value_counts(normalize=True)
df_counts = pd.DataFrame({'value': value_counts.index, 'count': value_counts.values})
df_counts['portion'] = df_counts['count'].apply(lambda x: x/total)
df_counts = df_counts.sort_values(by='portion', ascending=False)
df_counts
# Out:
#                                                 value     count   portion
# 0                                              Kidney  0.061181  0.000129
# 1                             Hepatobiliary Disorders  0.050633  0.000107
# 2                               Hepatobiliary Surgery  0.042194  0.000089
# 3                                  Infectious Disease  0.040084  0.000085
# 4                              Other General Medicine  0.040084  0.000085
# ..                                                ...       ...       ...
# 63  Cardiac Implants (Aicd, Defibrillator, Pacemaker)  0.002110  0.000004
# 64                                      Transurethral  0.002110  0.000004
# 65                               Respiratory Oncology  0.002110  0.000004
# 66                               Back/Neck Procedures  0.002110  0.000004
# 67                                    Cranial Surgery  0.002110  0.000004
#
# [68 rows x 3 columns]

# %%
counts = df_los['DRG Program'].value_counts().sort_values(ascending=False)
threshold = counts.quantile(0.8)
df_los['DRG Program'] = [x if counts[x] >= threshold and x != '-' else 'Other' for x in df_los['DRG Program']]
df_los['DRG Program']
# Out:
# 0                                Other
# 1                                Other
# 2                                Other
# 3                   Infectious Disease
# 4                   Infectious Disease
#                     ...
# 469                  Other Gi Medicine
# 470    Percutaneous Cardiac Procedures
# 471                              Other
# 472                 Infectious Disease
# 473              Hepatobiliary Surgery
# Name: DRG Program, Length: 474, dtype: object

# %%
counts = df_los['DRG Program'].value_counts().sort_values(ascending=False)
counts
# Out:
# Other                              248
# Kidney                              29
# Hepatobiliary Disorders             24
# Hepatobiliary Surgery               20
# Infectious Disease                  19
# Other General Medicine              19
# Other Gi Medicine                   16
# Intracranial Stroke                 13
# Digestive Cancer                    13
# Respiratory Diseases                13
# Heart Transplant                    12
# Other General Surgery               12
# Kidney Cancer                       12
# Percutaneous Cardiac Procedures     12
# Knee Joint Revision                 12
# Name: DRG Program, dtype: int64

# %%
df_los.groupby('DRG Program').size().plot.bar()
plt.show()

# %%
df_los.groupby('LOS Outlier').size().plot.bar()
plt.show()

# %%
df_los.groupby('Discharge Disposition').size().plot.bar()
plt.show()

# %%
df_los.groupby('Age').size().plot.bar()
plt.show()

# %% [markdown]
# #### Patient Status, DRG PROGRAM, LOS Outlier, Discharge Disposition are all categorical features, it's necessary to convert categorical features to numerical. I use one-hot-encoding here

# %%
#                     
categorical_columns = [
                    'DRG Program',
                    'Patient Status',                     
                    'Discharge Disposition'
                      ]
for col in categorical_columns:
    #if the original column is present replace it with a one-hot
    if col in X.columns:
        one_hot_encoded = pd.get_dummies(X[col])
        X = X.drop(col, axis=1)
        X = X.join(one_hot_encoded, lsuffix='_left', rsuffix='_right')
        
print(X.shape)
# Out:
# (474, 91)

# %%
#                     
categorical_columns = [
                    'DRG Program',
                    'Patient Status',                     
                    'Discharge Disposition'
                      ]
for col in categorical_columns:
    #if the original column is present replace it with a one-hot
    if col in df_los.columns:
        one_hot_encoded = pd.get_dummies(df_los[col])
        df_los = df_los.drop(col, axis=1)
        df_los = df_los.join(one_hot_encoded, lsuffix='_left', rsuffix='_right')
        
print(df_los.shape)
# Out:
# (474, 47)

# %%
print(df_los.shape)
print(X.shape)
#XnotNorm = np.array(X.copy())
XnotNorm = df_los.copy()
print('XnotNorm ', XnotNorm.shape)

ynotNorm = y.copy()
print('ynotNorm ', ynotNorm.shape)
# Out:
# (474, 47)
# (474, 91)
# XnotNorm  (474, 47)
# ynotNorm  (474,)

# %%
XnotNorm = XnotNorm.drop('Accepting Physician Specialty',1)
XnotNorm = XnotNorm.drop('Required Level Of Care',1)
XnotNorm = XnotNorm.drop('Requested Treatment Intervention',1)
XnotNorm = XnotNorm.drop('Gender',1)
XnotNorm = XnotNorm.drop('Payor',1)
XnotNorm = XnotNorm.drop('LOA (Mark X if Yes)', 1)
XnotNorm = XnotNorm.drop('From Where Patient Admitted to Referring Facility', 1)
XnotNorm = XnotNorm.drop('EMTALA Y/N(Patient Status Details)', 1)
XnotNorm = XnotNorm.drop('Special Considerations', 1)
XnotNorm = XnotNorm.drop('Transfer Back Agreement', 1)
XnotNorm = XnotNorm.drop('Transfer Referral Source', 1)
XnotNorm = XnotNorm.drop('Infection Precaution',1)
XnotNorm = XnotNorm.drop('Request Status',1)
XnotNorm = XnotNorm.drop('LOS',1)
XnotNorm = XnotNorm.drop('ICU LOS',1)
XnotNorm = XnotNorm.drop('LOS Outlier',1)
XnotNorm = XnotNorm.drop('County',1)
# XnotNorm = XnotNorm.drop('DRG PROGRAM',1)
# XnotNorm = XnotNorm.drop('PAYOR',1)
XnotNorm.columns
# Out:
# Index(['TC_ID', 'Age', 'Digestive Cancer', 'Heart Transplant',
#        'Hepatobiliary Disorders', 'Hepatobiliary Surgery',
#        'Infectious Disease', 'Intracranial Stroke', 'Kidney', 'Kidney Cancer',
#        'Knee Joint Revision', 'Other_left', 'Other General Medicine',
#        'Other General Surgery', 'Other Gi Medicine',
#        'Percutaneous Cardiac Procedures', 'Respiratory Diseases', 'ER',
#        'Inpatient', 'Acute-Another Hosp', 'Expired', 'Home Health Org',
#        'Home/Self Care', 'Hospice', 'Intermediate Care', 'Long Term Care',
#        'Other_right', 'Rehab', 'SNF', 'Short Term'],
#       dtype='object')

# %%
ynotNorm
# Out:
# 0       6.54
# 1       6.00
# 2       6.13
# 3       2.00
# 4       6.58
#        ...
# 469     6.00
# 470     2.00
# 471     5.00
# 472     6.23
# 473    22.00
# Name: LOS, Length: 474, dtype: float64

# %%
# clean data
# 89+ to 89
XnotNorm.replace('Unknown', pd.np.nan, inplace=True)
XnotNorm.replace('89+', 90, inplace=True)

# %% [markdown]
# Normalize X

# %%
x = XnotNorm.values #returns a numpy array
scaler = preprocessing.StandardScaler()
x_scaled = scaler.fit_transform(x)
XNorm = pd.DataFrame(x_scaled, columns=XnotNorm.columns)
#print(XNorm)
#print(y)
print('X normalized')
# Out:
# X normalized

# %%
XNorm.columns = XNorm.columns.astype(str) 
XNorm
# Out:
#         TC_ID       Age  Digestive Cancer  Heart Transplant  \
# 0   -1.651078  1.141442         -0.167927         -0.161165
# 1   -1.643176 -0.145400         -0.167927         -0.161165
# 2   -1.630125  0.088571         -0.167927         -0.161165
# 3   -1.623564 -0.320879         -0.167927         -0.161165
# 4   -1.623070 -0.964300         -0.167927         -0.161165
# ..        ...       ...               ...               ...
# 469  1.745950  0.264050         -0.167927         -0.161165
# 470  1.750253  0.965964         -0.167927         -0.161165
# 471  1.761823 -0.730329         -0.167927         -0.161165
# 472  1.769301 -0.554850         -0.167927         -0.161165
# 473  1.769654  1.609385         -0.167927         -0.161165
#
#      Hepatobiliary Disorders  Hepatobiliary Surgery  Infectious Disease  \
# 0                   -0.23094              -0.209888           -0.204348
# 1                   -0.23094              -0.209888           -0.204348
# 2                   -0.23094              -0.209888           -0.204348
# 3                   -0.23094              -0.209888            4.893605
# 4                   -0.23094              -0.209888            4.893605
# ..                       ...                    ...                 ...
# 469                 -0.23094              -0.209888           -0.204348
# 470                 -0.23094              -0.209888           -0.204348
# 471                 -0.23094              -0.209888           -0.204348
# 472                 -0.23094              -0.209888            4.893605
# 473                 -0.23094               4.764452           -0.204348
#
#      Intracranial Stroke    Kidney  Kidney Cancer  ...   Expired  \
# 0              -0.167927 -0.255281      -0.161165  ... -0.255281
# 1              -0.167927 -0.255281      -0.161165  ... -0.255281
# 2              -0.167927 -0.255281      -0.161165  ... -0.255281
# 3              -0.167927 -0.255281      -0.161165  ...  3.917247
# 4              -0.167927 -0.255281      -0.161165  ...  3.917247
# ..                   ...       ...            ...  ...       ...
# 469            -0.167927 -0.255281      -0.161165  ... -0.255281
# 470            -0.167927 -0.255281      -0.161165  ... -0.255281
# 471            -0.167927 -0.255281      -0.161165  ... -0.255281
# 472            -0.167927 -0.255281      -0.161165  ... -0.255281
# 473            -0.167927 -0.255281      -0.161165  ... -0.255281
#
#      Home Health Org  Home/Self Care   Hospice  Intermediate Care  \
# 0          -0.565981       -0.846990 -0.282359           5.350234
# 1          -0.565981       -0.846990 -0.282359          -0.186908
# 2           1.766844       -0.846990 -0.282359          -0.186908
# 3          -0.565981       -0.846990 -0.282359          -0.186908
# 4          -0.565981       -0.846990 -0.282359          -0.186908
# ..               ...             ...       ...                ...
# 469        -0.565981        1.180652 -0.282359          -0.186908
# 470        -0.565981        1.180652 -0.282359          -0.186908
# 471         1.766844       -0.846990 -0.282359          -0.186908
# 472         1.766844       -0.846990 -0.282359          -0.186908
# 473        -0.565981       -0.846990 -0.282359          -0.186908
#
#      Long Term Care  Other_right     Rehab       SNF  Short Term
# 0         -0.113228    -0.079809 -0.167927 -0.264532   -0.122431
# 1         -0.113228    -0.079809 -0.167927 -0.264532   -0.122431
# 2         -0.113228    -0.079809 -0.167927 -0.264532   -0.122431
# 3         -0.113228    -0.079809 -0.167927 -0.264532   -0.122431
# 4         -0.113228    -0.079809 -0.167927 -0.264532   -0.122431
# ..              ...          ...       ...       ...         ...
# 469       -0.113228    -0.079809 -0.167927 -0.264532   -0.122431
# 470       -0.113228    -0.079809 -0.167927 -0.264532   -0.122431
# 471       -0.113228    -0.079809 -0.167927 -0.264532   -0.122431
# 472       -0.113228    -0.079809 -0.167927 -0.264532   -0.122431
# 473       -0.113228    -0.079809 -0.167927  3.780254   -0.122431
#
# [474 rows x 30 columns]

# %%
# SPLIT into Train & Test

X_train, X_test, y_train, y_test = train_test_split(XNorm, y, test_size=0.2, random_state=7)
print ('X_train: ', X_train.shape)
print ('X_test: ', X_test.shape)
print ('y_train: ', y_train.shape)
print ('y_test: ', y_test.shape)
# Out:
# X_train:  (379, 30)
# X_test:  (95, 30)
# y_train:  (379,)
# y_test:  (95,)

# %%
# Test Models and evaluation metric
seed = 42
scoring = 'accuracy' 

# Spot Check Algorithms
Mymodels = []
Mymodels.append(('LinearReg', LinearRegression()))
Mymodels.append(('Ridge', Ridge(alpha=0.5)))
Mymodels.append(('RandomForestRegressor', RandomForestRegressor(n_estimators=100, max_depth=5, random_state=42)))
Mymodels.append(('Lasso', Lasso(alpha=0.1)))

# Evaluate each model in turn
results = []
names = []
# ,error_score='raise'
for name, model in Mymodels:
    # Train the model on the training data
    model.fit(X_train, y_train)
    # Make predictions on the test data
    y_pred = model.predict(X_test)
    # Calculate the Mean Squared Error
    mse = mean_squared_error(y_test, y_pred)
    print("%s mse: %f "% (name, mse))
    
    
    
#     kfold = model_selection.KFold(n_splits=10, random_state=seed, shuffle=True)
#     cv_results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
#     results.append(cv_results)
#     names.append(name)
#     msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
#     print(msg)
# Out:
# LinearReg mse: 190.690829
# Ridge mse: 191.016929
# RandomForestRegressor mse: 185.392176
# Lasso mse: 189.353118

# %% [markdown]
# # Linear Regressor

# %%
# Optimize hyper params for one model

Linearmodel = LinearRegression()

param_grid = [{},]

Linearmodel = GridSearchCV(Linearmodel, param_grid, cv=5, scoring=scoring)
Linearmodel.fit(XNorm, y)

print(Linearmodel.best_estimator_)
# Out:
# LinearRegression()

# %%
Linearmodel = LinearRegression()

# %%
Linearmodel.fit(XNorm, y)
final_predictions = Linearmodel.predict(X_test)
# Generate the R-squared
r2 = r2_score(y_test, final_predictions)
# cm = confusion_matrix(y_test, final_predictions)
print('R-squared:', r2)
mse = mean_squared_error(y_test, final_predictions)

print("Mean Squared Error:", mse)
# Out:
# R-squared: 0.13313919997272627
# Mean Squared Error: 167.8671272708205

# %% [markdown]
# # Random Forest Regressor

# %%
# Optimize hyper params for one model

model = RandomForestRegressor(n_estimators=100, max_depth=5, random_state=42)

param_grid = [{},]

grid_search = GridSearchCV(model, param_grid, cv=5, scoring=scoring)
grid_search.fit(XNorm, y)

print(grid_search.best_estimator_)
# Out:
# RandomForestRegressor(max_depth=5, random_state=42)

# %%
model = RandomForestRegressor(max_depth=5, random_state=42)

# %%
# FEATURE IMPORTANCE - NORMALIZED - last model

trainFinalFI = XNorm
yFinalFI = y

model.fit(trainFinalFI,yFinalFI)

FI_model = pd.DataFrame({"Feature Importance":model.feature_importances_,}, index=trainFinalFI.columns)
FI_model[FI_model["Feature Importance"] > 0.005].sort_values("Feature Importance").plot(kind="barh",figsize=(15,25))
plt.xticks(rotation=90)
plt.xticks(rotation=90)
plt.show()

# %%
# List of important features for model
FI_model = pd.DataFrame({"Feature Importance":model.feature_importances_,}, index=trainFinalFI.columns)
FI_model=FI_model.sort_values('Feature Importance', ascending = False)
print(FI_model[FI_model["Feature Importance"] > 0.001])
# Out:
#                         Feature Importance
# TC_ID                             0.310543
# Age                               0.183882
# Long Term Care                    0.134398
# Inpatient                         0.084351
# Expired                           0.057582
# SNF                               0.052414
# ER                                0.041435
# Home/Self Care                    0.040026
# Heart Transplant                  0.031533
# Other_left                        0.017242
# Other General Medicine            0.015951
# Rehab                             0.009621
# Knee Joint Revision               0.007119
# Acute-Another Hosp                0.004102
# Other General Surgery             0.003599
# Home Health Org                   0.002504
# Hepatobiliary Surgery             0.002226

# %%
# Model fit and evaluation on test

final_predictions = model.predict(X_test)

# %%
# Generate the R-squared
r2 = r2_score(y_test, final_predictions)
print('R-squared:', r2)
mse = mean_squared_error(y_test, final_predictions)

print("Mean Squared Error:", mse)
# Out:
# R-squared: 0.7526965038167623
# Mean Squared Error: 47.89018890576696

# %% [markdown]
# # Ridge

# %%
# Optimize hyper params for one model

Ridgemodel = Ridge(alpha=0.5)

param_grid = [{},]

grid_search = GridSearchCV(Ridgemodel, param_grid, cv=5, scoring=scoring)
grid_search.fit(XNorm, y)

print(grid_search.best_estimator_)
# Out:
# Ridge(alpha=0.5)

# %%
# Model fit and evaluation on test
trainFinalFI = XNorm
yFinalFI = y

Ridgemodel.fit(trainFinalFI,yFinalFI)

Ridge_pred = Ridgemodel.predict(X_test)

# %%
# Generate the R-squared
r2 = r2_score(y_test, Ridge_pred)
print('R-squared:', r2)
mse = mean_squared_error(y_test, Ridge_pred)

print("Mean Squared Error:", mse)
# Out:
# R-squared: 0.13001407007137455
# Mean Squared Error: 168.47230699387586

# %% [markdown]
# # Lasso

# %%
# Optimize hyper params for one model

Lassomodel = Lasso(alpha=0.1)

param_grid = [{},]

grid_search = GridSearchCV(Lassomodel, param_grid, cv=5, scoring=scoring)
grid_search.fit(XNorm, y)

print(grid_search.best_estimator_)
# Out:
# Lasso(alpha=0.1)

# %%
# Model fit and evaluation on test
trainFinalFI = XNorm
yFinalFI = y

Lassomodel.fit(trainFinalFI,yFinalFI)

Lasso_pred = Lassomodel.predict(X_test)

# %%
# Generate the R-squared
r2 = r2_score(y_test, Lasso_pred)
print('R-squared:', r2)
mse = mean_squared_error(y_test, Lasso_pred)

print("Mean Squared Error:", mse)
# Out:
# R-squared: 0.13201501819232997
# Mean Squared Error: 168.08482446741698

# %%
# 1. binary 67 => feature selection MRMR dummy variables
# 2. singluar value decomposition 10% PCA components
